# %%
Chains:

- glue that connects prompt + model + optional memory/ tools / output handling 

Types:
1] LLMChains
2] SimpleSequentialChain
3] SequentialChain
4] ConversationChain
5] RetrievealQAChain
6] ConversationalRetrievealChain
7] MapReduceChain
8] RefineChain
9] StuffDocumentsChain
10] RouterChain
11] MulltiPromptChain
12] TransformChain
