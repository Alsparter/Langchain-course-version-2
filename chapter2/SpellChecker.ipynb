# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

S1 = " 71 Main St Hempstead, NY 11550 United States
"
S2 = " 71 Main St, Hempstead, NY 11550, United States
"

e1 = model.encode(S1)
e2 = model.encode(S2)

Similarity = util.cos_sim(e1,e2)
print("Similarity: ", Similarity.item())
print(Similarity)
# Out:
# Similarity:  0.9905161261558533
# tensor([[0.9905]])
